# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import funcs
import imp
import random
import mne
from scipy.signal import hilbert
imp.reload(funcs)
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
# Out:
# C:\Users\Tianyi Zheng\AppData\Local\Temp\ipykernel_26124\1663922100.py:11: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp

# %%
load_path = os.path.join('..', '..', '..', 'data', 'subjects_rest_eeg.pkl')
subjects_rest_eeg = pd.read_pickle(load_path)
# 7.4s

# %%
exp_info = funcs.load_info()
exp_info["R pre"] = None
exp_info["R post"] = None

# %%
task_time_name = ['pre', 'post']
for subject_id in range(1, 27):
    for tasktime in range (1, 3):
        raw = subjects_rest_eeg[subjects_rest_eeg['subject id'] == subject_id][task_time_name[tasktime-1]].values[0]
        print("\nsubject_id: ", subject_id, " tasktime: ", task_time_name[tasktime-1], "\n")

        band = [55, 95] # high gamma band: 55-95 Hz
        eeg = raw.filter(band[0], band[1], verbose=False).get_data()[1:32,:]
        R = funcs.synchrony_R(eeg)

        idx = exp_info[(exp_info['subject id'] == subject_id)].index[0]
        exp_info.at[idx, 'R '+task_time_name[tasktime-1]] = R

# 5min 40s
# Out:
# subject_id:  1  tasktime:  pre
#
#
# subject_id:  1  tasktime:  post
#
#
# subject_id:  2  tasktime:  pre
#
#
# subject_id:  2  tasktime:  post
#
#
# subject_id:  3  tasktime:  pre
#
#
# subject_id:  3  tasktime:  post
#
#
# subject_id:  4  tasktime:  pre
#
#
# subject_id:  4  tasktime:  post
#
#
# subject_id:  5  tasktime:  pre
#
#
# subject_id:  5  tasktime:  post
#
#
# subject_id:  6  tasktime:  pre
#
#
# subject_id:  6  tasktime:  post
#
#
# subject_id:  7  tasktime:  pre
#
#
# subject_id:  7  tasktime:  post
#
#
# subject_id:  8  tasktime:  pre
#
#
# subject_id:  8  tasktime:  post
#
#
# subject_id:  9  tasktime:  pre
#
#
# subject_id:  9  tasktime:  post
#
#
# subject_id:  10  tasktime:  pre
#
#
# subject_id:  10  tasktime:  post
#
#
# subject_id:  11  tasktime:  pre
#
#
# subject_id:  11  tasktime:  post
#
#
# subject_id:  12  tasktime:  pre
#
#
# subject_id:  12  tasktime:  post
#
#
# subject_id:  13  tasktime:  pre
#
#
# subject_id:  13  tasktime:  post
#
#
# subject_id:  14  tasktime:  pre
#
#
# subject_id:  14  tasktime:  post
#
#
# subject_id:  15  tasktime:  pre
#
#
# subject_id:  15  tasktime:  post
#
#
# subject_id:  16  tasktime:  pre
#
#
# subject_id:  16  tasktime:  post
#
#
# subject_id:  17  tasktime:  pre
#
#
# subject_id:  17  tasktime:  post
#
#
# subject_id:  18  tasktime:  pre
#
#
# subject_id:  18  tasktime:  post
#
#
# subject_id:  19  tasktime:  pre
#
#
# subject_id:  19  tasktime:  post
#
#
# subject_id:  20  tasktime:  pre
#
#
# subject_id:  20  tasktime:  post
#
#
# subject_id:  21  tasktime:  pre
#
#
# subject_id:  21  tasktime:  post
#
#
# subject_id:  22  tasktime:  pre
#
#
# subject_id:  22  tasktime:  post
#
#
# subject_id:  23  tasktime:  pre
#
#
# subject_id:  23  tasktime:  post
#
#
# subject_id:  24  tasktime:  pre
#
#
# subject_id:  24  tasktime:  post
#
#
# subject_id:  25  tasktime:  pre
#
#
# subject_id:  25  tasktime:  post
#
#
# subject_id:  26  tasktime:  pre
#
#
# subject_id:  26  tasktime:  post

# %%
save_path = os.path.join('..', '..', '..', 'data', 'subjects_rest_excind' +'.pkl')
exp_info.to_pickle(save_path)
